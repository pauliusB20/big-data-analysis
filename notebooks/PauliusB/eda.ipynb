# %%
import duckdb
import numpy as np
import pandas as pd
from datetime import datetime
import csv

# %%
LIMIT = 1000

# %%
conn = duckdb.connect()
ship_data = conn.execute(f"""
    SELECT * FROM read_csv_auto("../../../aisdk-2025-02-28.csv") LIMIT {LIMIT}              
""").df()

ship_data
       
    # write to csv file
# Out:
#             # Timestamp Type of mobile       MMSI   Latitude  Longitude  \
# 0   2025-02-28 00:00:00        Class A  266239000  54.609702  13.715475
# 1   2025-02-28 00:00:00   Base Station    2190064  56.716567  11.519037
# 2   2025-02-28 00:00:00        Class A  219002136  57.182753   8.523752
# 3   2025-02-28 00:00:00        Class A  219002136  57.182753   8.523752
# 4   2025-02-28 00:00:00   Base Station    2194006  55.538870   5.033200
# ..                  ...            ...        ...        ...        ...
# 995 2025-02-28 00:00:04        Class A  219024715  57.492593  10.504980
# 996 2025-02-28 00:00:04        Class A  257980000  55.466715  10.528507
# 997 2025-02-28 00:00:04        Class A  219006283  56.764297   8.863188
# 998 2025-02-28 00:00:04        Class A  219022903  56.152152  10.254583
# 999 2025-02-28 00:00:04        Class A  219022000  57.121628   8.598483
#
#                      Navigational status  ROT   SOG    COG  Heading  ...  \
# ...

# %%
ship_data.shape
# Out:
# (1000, 26)

# %%
ship_data.columns
# Out:
# Index(['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude',
#        'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO',
#        'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length',
#        'Type of position fixing device', 'Draught', 'Destination', 'ETA',
#        'Data source type', 'A', 'B', 'C', 'D'],
#       dtype='str')

# %%
# TODO:
# Perform anomaly detetion tasks
ship_data.dropna()
# Out:
#             # Timestamp Type of mobile       MMSI   Latitude  Longitude  \
# 460 2025-02-28 00:00:02        Class A  212900000  56.156172  12.413825
# 461 2025-02-28 00:00:02        Class A  212900000  56.156172  12.413825
# 472 2025-02-28 00:00:02        Class A  219001431  54.999220   9.671183
#
#         Navigational status  ROT  SOG    COG  Heading  ... Length  \
# 460  Under way using engine  0.0  9.7  128.0      126  ...     88
# 461  Under way using engine  0.0  9.7  128.0      126  ...     88
# 472  Under way using engine  0.0  0.0  230.8       50  ...     40
#
#     Type of position fixing device Draught           Destination  \
# 460                            GPS     3.1                 SEMMA
# 461                            GPS     3.1                 SEMMA
# 472                            GPS     2.0  BALLEBRO - HARDESHOJ
#
#                     ETA  Data source type   A   B  C  D
# 460 2025-02-28 05:00:00               AIS  77  11  8  5
# ...

# %%
np.unique(ship_data[ship_data["Type of mobile"] == "Class A"]["# Timestamp"])
# Out:
# array(['2025-02-28T00:00:00.000000', '2025-02-28T00:00:01.000000',
#        '2025-02-28T00:00:02.000000', '2025-02-28T00:00:03.000000',
#        '2025-02-28T00:00:04.000000'], dtype='datetime64[us]')

# %%
np.unique(ship_data[ship_data["Type of mobile"] == "Class A"]["# Timestamp"])
# Out:
# array(['2025-02-28T00:00:00.000000', '2025-02-28T00:00:01.000000',
#        '2025-02-28T00:00:02.000000', '2025-02-28T00:00:03.000000',
#        '2025-02-28T00:00:04.000000'], dtype='datetime64[us]')

# %%
np.unique(ship_data["MMSI"])
# Out:
# array([     3638,   2190047,   2190048,   2190052,   2190064,   2190065,
#          2190066,   2190067,   2190068,   2190069,   2190071,   2190073,
#          2190074,   2190076,   2190077,   2194005,   2194006,   2194016,
#          2573115,   2573125,   2573135,   2573145,   2655130,   2655135,
#          2655140,   2655146,   2655148,   2655150,   2655185, 205210000,
#        209336000, 209531000, 209974000, 210046000, 210071000, 210144000,
#        210359000, 210399000, 211169660, 211188000, 211190000, 211209290,
#        211282410, 211291160, 211325200, 211364330, 211410690, 211493380,
#        211543450, 211731030, 211736820, 211757470, 211833390, 211866190,
#        211870240, 212613000, 212797000, 212801000, 212880000, 212882000,
#        212900000, 215116000, 215195000, 215489000, 218000630, 218005000,
#        218041490, 218085000, 218413000, 218601000, 218805000, 218816000,
#        219000187, 219000245, 219000368, 219000431, 219000577, 219000604,
# ...

# %%
ship_data[ship_data["MMSI"] == 3638]
# Out:
#             # Timestamp Type of mobile  MMSI  Latitude  Longitude  \
# 321 2025-02-28 00:00:01        Class A  3638      91.0        0.0
# 323 2025-02-28 00:00:01        Class A  3638      91.0        0.0
# 326 2025-02-28 00:00:01        Class A  3638      91.0        0.0
# 327 2025-02-28 00:00:01        Class A  3638      91.0        0.0
# 328 2025-02-28 00:00:01        Class A  3638      91.0        0.0
# 330 2025-02-28 00:00:01        Class A  3638      91.0        0.0
#
#     Navigational status  ROT  SOG  COG  Heading  ... Length  \
# 321       Unknown value  NaN  NaN  NaN     <NA>  ...   <NA>
# 323       Unknown value  NaN  NaN  NaN     <NA>  ...   <NA>
# 326       Unknown value  NaN  NaN  NaN     <NA>  ...   <NA>
# 327       Unknown value  NaN  NaN  NaN     <NA>  ...   <NA>
# 328       Unknown value  NaN  NaN  NaN     <NA>  ...   <NA>
# 330       Unknown value  NaN  NaN  NaN     <NA>  ...   <NA>
#
# ...

# %%
ship_data.dtypes
# Out:
# # Timestamp                       datetime64[us]
# Type of mobile                               str
# MMSI                                       int64
# Latitude                                 float64
# Longitude                                float64
# Navigational status                          str
# ROT                                      float64
# SOG                                      float64
# COG                                      float64
# Heading                                    Int64
# IMO                                          str
# Callsign                                     str
# Name                                         str
# Ship type                                    str
# Cargo type                                   str
# Width                                      Int64
# Length                                     Int64
# Type of position fixing device               str
# Draught                                  float64
# ...

# %%
ship_data[["Draught"]].dropna()
# Out:
#      Draught
# 147      5.5
# 170      5.2
# 296      2.5
# 349      3.0
# 452      2.5
# 457      2.5
# 460      3.1
# 461      3.1
# 472      2.0
# 520      9.1
# 521      9.1
# 543      2.5
# 544      2.5
# 552      6.3
# 553      2.5
# 611      1.5
# 612      1.5
# 613      2.0
# 614      1.5
# 638      2.5
# 682      5.2
# 685      5.2
# 710      3.0
# 750      3.4
# 752      3.4
# 765      4.5
# 766      4.5
# 767      5.5
# 768      4.5
# 769      5.5
# 788      5.4
# 792      3.3
# 793      5.4
# 844      2.5
# 850      2.5
# 939      2.5
# 946      3.0
